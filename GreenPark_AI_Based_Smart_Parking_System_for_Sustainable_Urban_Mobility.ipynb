# %%
# !pip install ultralytics opencv-python matplotlib numpy pandas

# %%
# Basic Setup
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# For Deep Learning
import torch
from ultralytics import YOLO

# %%
# Check if GPU is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Environment Ready - Using {device.upper()} for training")
# Out:
# Environment Ready - Using CPU for training
